# %% [markdown]
# # Tarea 1

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# ## 1.Imprime los primeros 7 renglones del archivo Lol-Champions.csv.

# %%
df = pd.read_csv("LoL-Champions.csv")

# %%
df[:7]
# Out:
#    Id     Name         Class  Style  Difficulty DamageType  Damage  \
# 0   1   Aatrox       Warrior      3           2          P       3
# 1   2     Ahri          Mage     10           2          M       3
# 2   3    Akali       Assasin      7           2         PM       3
# 3   4  Alistar  Tank-Support      7           1          M       1
# 4   5    Amumu          Tank      9           1          M       2
# 5   6   Anivia          Mage     10           3          M       3
# 6   7    Annie          Mage     10           1          M       3
#
#    Sturdiness  Crowd-Control  Mobility  Functionality
# 0           3              2         2            2.0
# 1           1              2         3            1.0
# 2           1              1         3            1.0
# 3           3              3         1            2.0
# 4           3              3         1            1.0
# 5           1              3         1            2.0
# ...

# %% [markdown]
# ## 2.Imprime los últimos 5 renglones del archivo.

# %%
df[-5:]
# Out:
#       Id    Name         Class  Style  Difficulty DamageType  Damage  \
# 140  141     Zed       Assasin      6           3          P       3
# 141  142   Ziggs          Mage      9           2          M       3
# 142  143  Zilean  Mage-Support     10           2          M       2
# 143  144     Zoe          Mage     10           3          M       3
# 144  145    Zyra  Mage-Support     10           2          M       3
#
#      Sturdiness  Crowd-Control  Mobility  Functionality
# 140           1              1         3            1.0
# 141           1              2         2            1.0
# 142           1              2         2            3.0
# 143           1              2         2            1.0
# 144           1              3         1            1.0

# %% [markdown]
# ## 3.Remueve la columna Id y haz que Name sea el nuevo índice.

# %%
del df["Id"]

# %%
df = df.set_index("Name")

# %%
df
# Out:
#                 Class  Style  Difficulty DamageType  Damage  Sturdiness  \
# Name
# Aatrox        Warrior      3           2          P       3           3
# Ahri             Mage     10           2          M       3           1
# Akali         Assasin      7           2         PM       3           1
# Alistar  Tank-Support      7           1          M       1           3
# Amumu            Tank      9           1          M       2           3
# ...               ...    ...         ...        ...     ...         ...
# Zed           Assasin      6           3          P       3           1
# Ziggs            Mage      9           2          M       3           1
# Zilean   Mage-Support     10           2          M       2           1
# Zoe              Mage     10           3          M       3           1
# Zyra     Mage-Support     10           2          M       3           1
#
#          Crowd-Control  Mobility  Functionality
# Name
# ...

# %% [markdown]
# ## 4. La base de datos está en orden alfabético ascendente en base al nombre del campeón. Cambia la base de datos para que esté en orden alfabético descendente en base al nombre del campeón.

# %%
df = df.sort_values(by="Name", ascending=False)

# %%
df
# Out:
#                 Class  Style  Difficulty DamageType  Damage  Sturdiness  \
# Name
# Zyra     Mage-Support     10           2          M       3           1
# Zoe              Mage     10           3          M       3           1
# Zilean   Mage-Support     10           2          M       2           1
# Ziggs            Mage      9           2          M       3           1
# Zed           Assasin      6           3          P       3           1
# ...               ...    ...         ...        ...     ...         ...
# Amumu            Tank      9           1          M       2           3
# Alistar  Tank-Support      7           1          M       1           3
# Akali         Assasin      7           2         PM       3           1
# Ahri             Mage     10           2          M       3           1
# Aatrox        Warrior      3           2          P       3           3
#
#          Crowd-Control  Mobility  Functionality
# Name
# ...

# %% [markdown]
# ## 5. Filtra por todos los campeones cuyaClass sea Tank.

# %%
df[df["Class"] == 'Tank']
# Out:
#          Class  Style  Difficulty DamageType  Damage  Sturdiness  \
# Name
# Shen      Tank      5           2         PM       2           3
# Sejuani   Tank      8           2          M       2           2
# Rammus    Tank      7           1         PM       2           3
# Nunu      Tank      8           1          M       1           3
# Maokai    Tank      8           1          M       1           3
# Malphite  Tank      8           1          M       1           3
# Leona     Tank      9           1          M       1           3
# Amumu     Tank      9           1          M       2           3
#
#           Crowd-Control  Mobility  Functionality
# Name
# Shen                  2         2            3.0
# Sejuani               3         2            1.0
# Rammus                3         2            1.0
# Nunu                  2         1            2.0
# Maokai                3         1            2.0
# Malphite              3         1            1.0
# ...

# %% [markdown]
# ## 6. Crea  un  dataFrame  con  los  campeones  cuyo  nivel  de  dificultad  sea  menor  a 3, almacena  ese dataFrame en un archivo .csv llamado “noob.csv”.

# %%
noobsdf = df[df['Difficulty'] < 3]

# %%
noobsdf
# Out:
#                 Class  Style  Difficulty DamageType  Damage  Sturdiness  \
# Name
# Zyra     Mage-Support     10           2          M       3           1
# Zilean   Mage-Support     10           2          M       2           1
# Ziggs            Mage      9           2          M       3           1
# Zac      Tank-Warrior     10           1          M       2           3
# Yuumi         Support     10           1          M       1           1
# ...               ...    ...         ...        ...     ...         ...
# Amumu            Tank      9           1          M       2           3
# Alistar  Tank-Support      7           1          M       1           3
# Akali         Assasin      7           2         PM       3           1
# Ahri             Mage     10           2          M       3           1
# Aatrox        Warrior      3           2          P       3           3
#
#          Crowd-Control  Mobility  Functionality
# Name
# ...

# %%
noobsdf.to_csv('noob.csv')

# %% [markdown]
# ## 7. Filtra los campeones cuyo DamageType sea M y Crowd-Control sea 1.

# %%
df[(df['DamageType']=='M') & (df['Crowd-Control']==1)]
# Out:
#                     Class  Style  Difficulty DamageType  Damage  Sturdiness  \
# Name
# Yuumi             Support     10           1          M       1           1
# Vladimir     Mage-Warrior     10           2          M       3           2
# Sylas        Mage-Warrior      7           3          M       2           2
# Nidalee           Assasin      8           3          M       3           1
# Mordekaiser       Warrior      8           2          M       3           2
# Katarina     Mage-Assasin     10           3          M       3           1
# Kassadin     Mage-Assasin      9           2          M       3           2
# Karthus              Mage     10           2          M       3           1
# Evelynn           Assasin      8           2          M       2           2
#
#              Crowd-Control  Mobility  Functionality
# Name
# Yuumi                    1         3            3.0
# Vladimir                 1         1            1.0
# ...
